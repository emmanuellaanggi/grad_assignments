# %% [markdown]
# # Tugas 1 Perolehan Informasi Lanjut Genap 2022 - Pyterrier
#
# Pada tugas ini, digunakan library Python bernama Pyterrier yang merupakan versi Python dari [IR tool Terrier](http://terrier.org/). Installasi Pyterrier bisa dilihat pada [link dokumentasi Pyterrier](https://pyterrier.readthedocs.io/en/latest/). Anda juga dapat menggunakan file tutorial pyterrier di scele untuk mengerjakan tugas ini. Kerjakan dengan melengkapi #TODO pada setiap cell yang diberikan. Berikan dokumentasi yang jelas pada code Anda (comment pada line code yang diperlukan penjelasan). Disarankan menggunakan Google Colab untuk memudahkan pekerjaan Anda.

# %% [markdown]
# ## Prerequisites
#
# Instalasi Pyterrier

# %%
# !pip install python-terrier
# Out:
# Collecting python-terrier
#   Downloading python-terrier-0.8.0.tar.gz (97 kB)
#      |████████████████████████████████| 97 kB 4.3 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from python-terrier) (1.21.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from python-terrier) (1.3.5)
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from python-terrier) (4.63.0)
# Collecting pyjnius~=1.3.0
#   Downloading pyjnius-1.3.0-cp37-cp37m-manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 32.9 MB/s
# Collecting matchpy
#   Downloading matchpy-0.5.5-py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 6.7 MB/s
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from python-terrier) (0.0)
# Collecting deprecation
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Collecting chest
#   Downloading chest-0.2.3.tar.gz (9.6 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from python-terrier) (1.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from python-terrier) (2.23.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from python-terrier) (1.1.0)
# Collecting nptyping
#   Downloading nptyping-1.4.4-py3-none-any.whl (31 kB)
# Requirement already satisfied: more_itertools in /usr/local/lib/python3.7/dist-packages (from python-terrier) (8.12.0)
# Collecting ir_datasets>=0.3.2
#   Downloading ir_datasets-0.5.0-py3-none-any.whl (255 kB)
#      |████████████████████████████████| 255 kB 51.0 MB/s
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from python-terrier) (2.11.3)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.7/dist-packages (from python-terrier) (0.10.2)
# Collecting ir_measures>=0.2.0
#   Downloading ir_measures-0.2.3.tar.gz (41 kB)
#      |████████████████████████████████| 41 kB 285 kB/s
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from python-terrier) (0.3.4)
# Collecting warc3-wet>=0.2.3
#   Downloading warc3_wet-0.2.3-py3-none-any.whl (13 kB)
# Collecting lxml>=4.5.2
#   Downloading lxml-4.8.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.4 MB)
#      |████████████████████████████████| 6.4 MB 59.0 MB/s
# Collecting trec-car-tools>=2.5.4
#   Downloading trec_car_tools-2.6-py3-none-any.whl (8.4 kB)
# Collecting lz4>=3.1.1
#   Downloading lz4-4.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 46.4 MB/s
# Collecting pyautocorpus>=0.1.1
#   Downloading pyautocorpus-0.1.8-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (294 kB)
#      |████████████████████████████████| 294 kB 65.0 MB/s
# Collecting pyyaml>=5.3.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 61.7 MB/s
# Collecting ijson>=3.1.3
#   Downloading ijson-3.1.4-cp37-cp37m-manylinux2010_x86_64.whl (126 kB)
#      |████████████████████████████████| 126 kB 51.5 MB/s
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from ir_datasets>=0.3.2->python-terrier) (4.6.3)
# Collecting warc3-wet-clueweb09>=0.2.5
#   Downloading warc3-wet-clueweb09-0.2.5.tar.gz (17 kB)
# Collecting zlib-state>=0.1.3
#   Downloading zlib_state-0.1.5-cp37-cp37m-manylinux2010_x86_64.whl (72 kB)
#      |████████████████████████████████| 72 kB 1.5 MB/s
# Collecting pytrec-eval-terrier==0.5.1
#   Downloading pytrec_eval_terrier-0.5.1-cp37-cp37m-manylinux2010_x86_64.whl (291 kB)
#      |████████████████████████████████| 291 kB 54.7 MB/s
# Collecting cwl-eval>=1.0.10
#   Downloading cwl-eval-1.0.10.tar.gz (31 kB)
# Collecting pyndeval>=0.0.2
#   Downloading pyndeval-0.0.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (59 kB)
#      |████████████████████████████████| 59 kB 6.9 MB/s
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from pyjnius~=1.3.0->python-terrier) (1.15.0)
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from pyjnius~=1.3.0->python-terrier) (0.29.28)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->python-terrier) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->python-terrier) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->python-terrier) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->python-terrier) (2.10)
# Collecting cbor>=1.0.0
#   Downloading cbor-1.0.0.tar.gz (20 kB)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.7/dist-packages (from chest->python-terrier) (1.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from deprecation->python-terrier) (21.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->python-terrier) (2.0.1)
# Collecting multiset<3.0,>=2.0
#   Downloading multiset-2.1.1-py2.py3-none-any.whl (8.8 kB)
# Collecting typish>=1.7.0
#   Downloading typish-1.9.3-py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 2.9 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->deprecation->python-terrier) (3.0.7)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->python-terrier) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->python-terrier) (2.8.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn->python-terrier) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn->python-terrier) (3.1.0)
# Requirement already satisfied: patsy>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from statsmodels->python-terrier) (0.5.2)
# Building wheels for collected packages: python-terrier, ir-measures, cwl-eval, cbor, warc3-wet-clueweb09, chest, wget
#   Building wheel for python-terrier (setup.py) ... done
#   Created wheel for python-terrier: filename=python_terrier-0.8.0-py3-none-any.whl size=103883 sha256=57ad2a82407a8dbed3b0a3b363bd9783b211131c26c2b5eaff6697a9e1781514
#   Stored in directory: /root/.cache/pip/wheels/a8/ec/0c/fd9fcb409ad158d1f62534f9b1924b406f420f1a4170fb4132
#   Building wheel for ir-measures (setup.py) ... done
#   Created wheel for ir-measures: filename=ir_measures-0.2.3-py3-none-any.whl size=53217 sha256=2860955ca07b875a8a1869cd2caffab3e10ac9fe8068081b88b11e99f8561fb0
#   Stored in directory: /root/.cache/pip/wheels/b2/06/1b/b8dc2d9a9802a9c30dd3a28d4199061297df0034d8ab9b808a
#   Building wheel for cwl-eval (setup.py) ... done
#   Created wheel for cwl-eval: filename=cwl_eval-1.0.10-py3-none-any.whl size=37797 sha256=6e7f8ba14ce2d70e9948b3b750feaf59e64a2322de6d5c31df925c561f174f5b
#   Stored in directory: /root/.cache/pip/wheels/ff/e9/ff/d2b6d72d9feb0d0b1b11aacfaf5cd866717034615c2d194093
#   Building wheel for cbor (setup.py) ... done
#   Created wheel for cbor: filename=cbor-1.0.0-cp37-cp37m-linux_x86_64.whl size=51302 sha256=95d0ad7cc7a5636a61afb6b43159616638042c73709e18472ad396ed39a27446
#   Stored in directory: /root/.cache/pip/wheels/19/77/49/c9c2c8dc5848502e606e8579d0bbda18b850fb056a6c62239d
#   Building wheel for warc3-wet-clueweb09 (setup.py) ... done
#   Created wheel for warc3-wet-clueweb09: filename=warc3_wet_clueweb09-0.2.5-py3-none-any.whl size=18922 sha256=17c3b2c45aae5d6d9a2bc0c5d4935e0a8a0f1b48a1a566cfdede78e8ba504038
#   Stored in directory: /root/.cache/pip/wheels/42/d4/3c/7c2b0c3d400ad744e4db69f2fde166655da2ed2198bfc02db6
#   Building wheel for chest (setup.py) ... done
#   Created wheel for chest: filename=chest-0.2.3-py3-none-any.whl size=7634 sha256=db6bc9f3b3d0c75517edf7bd12349e8a84605052257f18cca7617bf5b4d84ab2
#   Stored in directory: /root/.cache/pip/wheels/fc/f5/b9/c436e11300809e6b40d46a5d2592fb0bff89e0712f2e878dc7
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=c3f5e3f5cc5706e24bb663fa8b082915da998558b978c1f2784a3167e06fea25
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built python-terrier ir-measures cwl-eval cbor warc3-wet-clueweb09 chest wget
# Installing collected packages: cbor, zlib-state, warc3-wet-clueweb09, warc3-wet, typish, trec-car-tools, pyyaml, pytrec-eval-terrier, pyndeval, pyautocorpus, multiset, lz4, lxml, ijson, cwl-eval, wget, pyjnius, nptyping, matchpy, ir-measures, ir-datasets, deprecation, chest, python-terrier
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# Successfully installed cbor-1.0.0 chest-0.2.3 cwl-eval-1.0.10 deprecation-2.1.0 ijson-3.1.4 ir-datasets-0.5.0 ir-measures-0.2.3 lxml-4.8.0 lz4-4.0.0 matchpy-0.5.5 multiset-2.1.1 nptyping-1.4.4 pyautocorpus-0.1.8 pyjnius-1.3.0 pyndeval-0.0.2 python-terrier-0.8.0 pytrec-eval-terrier-0.5.1 pyyaml-6.0 trec-car-tools-2.6 typish-1.9.3 warc3-wet-0.2.3 warc3-wet-clueweb09-0.2.5 wget-3.2 zlib-state-0.1.5

# %% [markdown]
# ### Init

# %%
import pyterrier as pt
if not pt.started():
  pt.init()
# Out:
# terrier-assemblies 5.6 jar-with-dependencies not found, downloading to /root/.pyterrier...
# Done
# terrier-python-helper 0.0.6 jar not found, downloading to /root/.pyterrier...
# Done
# PyTerrier 0.8.0 has loaded Terrier 5.6 (built by craigmacdonald on 2021-09-17 13:27)

# %% [markdown]
# ## Indexing
#
# Akan dilakukan `indexing` pada file documents.csv.

# %%
# using beautify table from Google so it's easier to read and understand the data
from google.colab import data_table
data_table.enable_dataframe_formatter()

# %%
# Mounting from Google drive, since the file is big and cannot be accessed directly using the link
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Import Pandas library to read (and later to export) the CSV data,
import pandas as pd

pd.set_option('display.max_colwidth', 150)
docs_df = pd.read_csv("/content/gdrive/MyDrive/docs/documents.csv",dtype=str) # Convert directly to string to prevent confusion on pyterrier while indexing

# %%
# Melakukan indexing pada file documents.csv 

# Doing the indexing using DFIndexer (Referenced to: https://github.com/terrier-org/ecir2021tutorial/blob/main/notebooks/notebook1.ipynb)
indexer = pt.DFIndexer("./index", overwrite=True)
index_ref = indexer.index(docs_df["text"], docs_df["docno"])
index_ref.toString()

index = pt.IndexFactory.of(index_ref)

# %%
# Tampilkan statistik dari index yang sudah dibuat

# Getting statistic from the process done earlier
print(index.getCollectionStatistics().toString())
# Out:
# Number of documents: 369721
# Number of terms: 674552
# Number of postings: 30552936
# Number of fields: 0
# Number of tokens: 41306796
# Field names: []
# Positions:   false

# %% [markdown]
# ## Retrieval
#
# Melakukan `querying` pada documents yang sudah di-index.

# %%
# import dan tampilkan query dari query.csv dalam pandas dataframe

# Using pandas, import Query file that assigned to (query25)

query = pd.read_csv("/content/gdrive/MyDrive/docs/query25.csv",dtype=str) # Convert directly to string to prevent confusion on pyterrier while using the query
query
# Out:
#         qid                                          query
# 0    477200                                        badulla
# 1      9748                                          posix
# 2    157369                                     altai krai
# 3     22800                                   hmong people
# 4     80219                                         motown
# 5   1403378                             freestyle swimming
# 6    146323                                        kutaisi
# 7     97591                                       futurama
# 8     80765                                          thane
# 9    125608              order of st michael and st george
# 10   351608       royal college of physicians of edinburgh
# 11    81103                               20th century fox
# 12     4334                                        finland
# 13    21439                                     tina arena
# 14   113621                                 internet forum
# 15    90496                               muromachi period
# 16     2547                                  county dublin
# 17   488858                                      meath gaa
# 18   217759                          latvian higher league
# 19   189034                           ecclesiastical latin
# 20    90382                                   spiritualism
# 21   814731                                          akb48
# 22    14032            vice president of the united states
# 23    75643                        west germanic languages
# 24   189225                               city of bradford
# 25    25461                        smithsonian institution
# 26     4198                                  east pakistan
# 27  1897191                                       centrism
# 28   196387  bordeaux wine official classification of 1855
# 29    25130                                   paul gauguin

# %% [markdown]
# ### BM25

# %%
# Melakukan querying menggunakan scoring function BM25 dengan hanya mengambil top 10 documents untuk setiap query
# Tampilkan hasil search

# Using model BM25 to retrieve the query result on the indexed dataset, maximized the result to only top 10
res_BM25 = pt.BatchRetrieve(index, num_results=10, wmodel="BM25").transform(query)
res_BM25 # View the result
# Out:
#         qid   docid    docno  rank      score         query
# 0    477200  208491   477200     0  25.338037       badulla
# 1    477200  255842  2284397     1  24.129560       badulla
# 2    477200  353893  1657187     2  22.921779       badulla
# 3    477200  309486  1871845     3  21.892850       badulla
# 4    477200  329587  2041999     4  20.136955       badulla
# ..      ...     ...      ...   ...        ...           ...
# 290   25130   48485    25130     5  23.105140  paul gauguin
# 291   25130  319111      656     6  22.966842  paul gauguin
# 292   25130  346165   797254     7  22.530406  paul gauguin
# 293   25130   52430   371783     8  21.957649  paul gauguin
# 294   25130  318806   576623     9  21.933424  paul gauguin
#
# [295 rows x 6 columns]

# %%
# Simpan hasil search query BM25 dengan penamaan file Tugas1_[NPM]_BM25.res

pt.io.write_results(res_BM25, "Tugas1_2106678006_BM25.res") # Saving the result as the result report

# %% [markdown]
# ### Dirichlet Language Model

# %%
# Melakukan querying menggunakan scoring function Dirichlet Language Model dengan hanya mengambil top 10 documents untuk setiap query
# Tampilkan hasil search seluruh query

# Using model Dirichlet Language Model to retrieve the query result on the indexed dataset, maximized the result to only top 10
res_DLM = pt.BatchRetrieve(index, num_results=10, wmodel="DirichletLM").transform(query)
res_DLM # View the result
# Out:
#         qid   docid    docno  rank      score         query
# 0    477200  208491   477200     0  11.101568       badulla
# 1    477200  255842  2284397     1  10.779245       badulla
# 2    477200  353893  1657187     2  10.371110       badulla
# 3    477200  309486  1871845     3  10.357859       badulla
# 4    477200  329587  2041999     4   9.786116       badulla
# ..      ...     ...      ...   ...        ...           ...
# 290   25130  335190   883035     5  10.201234  paul gauguin
# 291   25130   17170  1935967     6  10.181358  paul gauguin
# 292   25130  204574  1352062     7  10.081640  paul gauguin
# 293   25130  319111      656     8  10.076113  paul gauguin
# 294   25130  346165   797254     9  10.068394  paul gauguin
#
# [295 rows x 6 columns]

# %%
# Simpan hasil search query Dirichlet Language Model dengan penamaan file Tugas1_[NPM]_DLM.res
pt.io.write_results(res_DLM, "Tugas1_2106678006_DLM.res") # Saving the result as the result report

# %% [markdown]
# ## Evaluation

# %%
# import qrels dan tampilkan. (hint: parse qrels dari local test collection)

# Using pandas, import qrels file that assigned to (qrels25) for evaluation
qrels = pt.io.read_qrels("/content/gdrive/MyDrive/docs/qrels25")
qrels
# Out:
#         qid    docno  label
# 0    477200   477200      2
# 1    477200  1189929      1
# 2    477200   746069      1
# 3    477200  2031478      1
# 4    477200  2284397      1
# ..      ...      ...    ...
# 908   25130  1348605      1
# 909   25130  2453559      1
# 910   25130  1976917      1
# 911   25130   576623      1
# 912   25130  1385260      1
#
# [913 rows x 3 columns]

# %% [markdown]
# ### BM25

# %%
# Melakukan evaluasi hasil retrieval BM25 seluruh query dengan metric evaluasi precision@10, recall@10, dan MRR

from pyterrier.measures import * # Download the library for the evaluation

qrels_BM25_ = pt.Experiment(
    [res_BM25], # The model that will be evaluated
    query, # Query that had been defined and used before 
    qrels, # Qrels that just imported 
    eval_metrics=[P@10, R@10, MRR], # Metrics for the evaluation
    names= ["BM25"], # Renaming the model
    perquery=True
)

qrels_BM25_.head(5)
# Out:
#     name     qid measure  value
# 42  BM25  113621      RR  0.000
# 43  BM25  113621    P@10  0.000
# 44  BM25  113621    R@10  0.000
# 27  BM25  125608      RR  0.125
# 28  BM25  125608    P@10  0.100

# %%
qrels_BM25 = qrels_BM25_.pivot(index=["qid", "name"], columns=["measure"], values="value")
qrels_BM25
# Out:
# measure       P@10      R@10        RR
# qid     name
# 113621  BM25   0.0  0.000000  0.000000
# 125608  BM25   0.1  0.012987  0.125000
# 14032   BM25   0.1  0.083333  1.000000
# 1403378 BM25   0.2  0.133333  0.500000
# 146323  BM25   0.3  0.375000  1.000000
# 157369  BM25   0.5  0.625000  1.000000
# 189034  BM25   0.1  0.166667  1.000000
# 189225  BM25   0.1  0.125000  0.166667
# 1897191 BM25   0.0  0.000000  0.000000
# 196387  BM25   0.3  0.500000  0.125000
# 21439   BM25   0.4  0.571429  1.000000
# 217759  BM25   0.4  0.444444  0.333333
# 22800   BM25   0.4  0.571429  1.000000
# 25130   BM25   0.2  0.333333  0.166667
# 25461   BM25   0.1  0.047619  1.000000
# 2547    BM25   0.2  0.125000  1.000000
# 351608  BM25   0.1  0.111111  0.333333
# 4198    BM25   0.2  0.117647  0.200000
# 4334    BM25   0.7  0.014344  0.500000
# 477200  BM25   0.3  0.500000  1.000000
# 488858  BM25   0.2  0.111111  1.000000
# 75643   BM25   0.3  0.375000  1.000000
# 80219   BM25   0.1  0.021739  0.333333
# 80765   BM25   0.3  0.428571  1.000000
# 81103   BM25   0.2  0.074074  1.000000
# 814731  BM25   0.3  0.428571  1.000000
# 90382   BM25   0.0  0.000000  0.000000
# 90496   BM25   0.2  0.142857  1.000000
# 9748    BM25   0.2  0.285714  1.000000
# 97591   BM25   0.1  0.045455  0.111111

# %%
# simpan hasil evaluasi dalam bentuk csv dengan row setiap query id dan kolom setiap metrik evaluasi. Format penamaan file: Tugas1_[NPM]_eval_BM25.csv
qrels_BM25.to_csv('Tugas1_2106678006_eval_BM25.csv')

# %% [markdown]
# ### Dirichlet Language Model

# %%
# Melakukan evaluasi hasil retrieval Dirichlet Language Model  seluruh query dengan metric evaluasi precision@10, recall@10, dan MRR

from pyterrier.measures import * # Download the library for the evaluation

qrels_DLM_ = pt.Experiment(
    [res_DLM], # The model that will be evaluated
    query, # Query that had been defined and used before 
    qrels, # Qrels that just imported 
    eval_metrics=[P@10, R@10, MRR], # Metrics for the evaluation
    names= ["Dirichlet Language Model"], # Renaming the model
    perquery=True
)

qrels_DLM = qrels_DLM_.pivot(index=["qid", "name"], columns="measure", values="value")
qrels_DLM
# Out:
# measure                           P@10      R@10        RR
# qid     name
# 113621  Dirichlet Language Model   0.0  0.000000  0.000000
# 125608  Dirichlet Language Model   0.1  0.012987  0.100000
# 14032   Dirichlet Language Model   0.1  0.083333  1.000000
# 1403378 Dirichlet Language Model   0.2  0.133333  0.200000
# 146323  Dirichlet Language Model   0.3  0.375000  1.000000
# 157369  Dirichlet Language Model   0.5  0.625000  1.000000
# 189034  Dirichlet Language Model   0.1  0.166667  1.000000
# 189225  Dirichlet Language Model   0.0  0.000000  0.000000
# 1897191 Dirichlet Language Model   0.0  0.000000  0.000000
# 196387  Dirichlet Language Model   0.3  0.500000  0.142857
# 21439   Dirichlet Language Model   0.4  0.571429  1.000000
# 217759  Dirichlet Language Model   0.4  0.444444  0.500000
# 22800   Dirichlet Language Model   0.4  0.571429  1.000000
# 25130   Dirichlet Language Model   0.1  0.166667  0.200000
# 25461   Dirichlet Language Model   0.2  0.095238  1.000000
# 2547    Dirichlet Language Model   0.2  0.125000  1.000000
# 351608  Dirichlet Language Model   0.1  0.111111  0.250000
# 4198    Dirichlet Language Model   0.2  0.117647  0.200000
# 4334    Dirichlet Language Model   0.7  0.014344  0.500000
# 477200  Dirichlet Language Model   0.3  0.500000  1.000000
# 488858  Dirichlet Language Model   0.2  0.111111  1.000000
# 75643   Dirichlet Language Model   0.3  0.375000  1.000000
# 80219   Dirichlet Language Model   0.1  0.021739  0.333333
# 80765   Dirichlet Language Model   0.3  0.428571  1.000000
# 81103   Dirichlet Language Model   0.2  0.074074  1.000000
# 814731  Dirichlet Language Model   0.3  0.428571  1.000000
# 90382   Dirichlet Language Model   0.0  0.000000  0.000000
# 90496   Dirichlet Language Model   0.2  0.142857  1.000000
# 9748    Dirichlet Language Model   0.2  0.285714  1.000000
# 97591   Dirichlet Language Model   0.1  0.045455  0.111111

# %%
# simpan hasil evaluasi dalam bentuk csv dengan row setiap query id dan kolom setiap metrik evaluasi. Format penamaan file: Tugas1_[NPM]_eval_DLM.csv
qrels_DLM.to_csv('Tugas1_2106678006_eval_DLM.csv')

# %% [markdown]
# ### Analisis Hasil
#
# 1. Lakukan evaluasi hasil keseluruhan query. Manakah metode yang memiliki efektivitas lebih baik antara BM25 dan LM? Apakah perbedaan skor yang diperoleh sigifikan secara statistik?
# 2. Lakukan evaluasi hasil per query. Pada query mana saja BM25 lebih unggul, dan pada query mana saja LM lebih unggul? Berikan analisis Anda mengapa hal ini bisa terjadi.
# 3. Query ID berapa yang memiliki nilai evaluasi terbaik dengan metode BM25? Query ID berapa yang memiliki nilai evaluasi terbaik dengan metode LM? Berikan analisis Anda mengapa hal ini bisa terjadi.
# 4. Query ID berapa yang memiliki nilai evaluasi terburuk dengan metode BM25? Query ID berapa yang memiliki nilai evaluasi terburuk dengan metode LM? Berikan analisis Anda mengapa hal ini bisa terjadi.
#
# ---

# %% [markdown]
# #### Lakukan evaluasi hasil keseluruhan query. Manakah metode yang memiliki efektivitas lebih baik antara BM25 dan LM? Apakah perbedaan skor yang diperoleh sigifikan secara statistik?

# %%
qrels_compare = pt.Experiment(
    [res_BM25, res_DLM], # The model that will be evaluated
    query, # Query that had been defined and used before 
    qrels, # Qrels that just imported 
    eval_metrics=[P@10, R@10, MRR], # Metrics for the evaluation
    names= ["BM25", "Dirichlet Language Model"], # Renaming the modeL
)

# %%
#Using the summary from function Experiment to view the result
#Although with very slight different, the summary result shows that 
#BM25 returns better value than Dirichlet's with higher precision, recall, and MRR.
qrels_compare
# Out:
#                        name      P@10      R@10        RR
# 0                      BM25  0.220000  0.225692  0.629815
# 1  Dirichlet Language Model  0.216667  0.217557  0.617910

# %% [markdown]
# **Hasil terbaik dari function Experiment bawaan dari pyTerrier menunjukkan bahwa model BM25 memiliki hasil Precission, Recall, dan MRR yang lebih baik daripada Dirichlet. Namun, hasil ini tetap *tidak signifikan* untuk menunjukkan efektivitas, sehingga bahkan dengan menggunakan p-value > 0.05, hasil tetap menunjukkan bahwa kedua model, performa-nya tidak signifikan.**

# %% [markdown]
# #### Lakukan evaluasi hasil per query. Pada query mana saja BM25 lebih unggul, dan pada query mana saja LM lebih unggul? Berikan analisis Anda mengapa hal ini bisa terjadi.

# %%
comp = pd.concat([qrels_DLM.reset_index(), qrels_BM25.reset_index()])
comp = comp.groupby(["qid", "name"]).apply(lambda x: x)
comp.head(62)

#189225, 196387, 	25130
# Out:
# measure      qid                      name  P@10      R@10        RR
# 0         113621                      BM25   0.0  0.000000  0.000000
# 0         113621  Dirichlet Language Model   0.0  0.000000  0.000000
# 1         125608                      BM25   0.1  0.012987  0.125000
# 1         125608  Dirichlet Language Model   0.1  0.012987  0.100000
# 2          14032                      BM25   0.1  0.083333  1.000000
# 2          14032  Dirichlet Language Model   0.1  0.083333  1.000000
# 3        1403378                      BM25   0.2  0.133333  0.500000
# 3        1403378  Dirichlet Language Model   0.2  0.133333  0.200000
# 4         146323                      BM25   0.3  0.375000  1.000000
# 4         146323  Dirichlet Language Model   0.3  0.375000  1.000000
# 5         157369                      BM25   0.5  0.625000  1.000000
# 5         157369  Dirichlet Language Model   0.5  0.625000  1.000000
# 6         189034                      BM25   0.1  0.166667  1.000000
# 6         189034  Dirichlet Language Model   0.1  0.166667  1.000000
# 7         189225                      BM25   0.1  0.125000  0.166667
# 7         189225  Dirichlet Language Model   0.0  0.000000  0.000000
# 8        1897191                      BM25   0.0  0.000000  0.000000
# 8        1897191  Dirichlet Language Model   0.0  0.000000  0.000000
# 9         196387                      BM25   0.3  0.500000  0.125000
# 9         196387  Dirichlet Language Model   0.3  0.500000  0.142857
# 10         21439                      BM25   0.4  0.571429  1.000000
# 10         21439  Dirichlet Language Model   0.4  0.571429  1.000000
# 11        217759                      BM25   0.4  0.444444  0.333333
# 11        217759  Dirichlet Language Model   0.4  0.444444  0.500000
# 12         22800                      BM25   0.4  0.571429  1.000000
# 12         22800  Dirichlet Language Model   0.4  0.571429  1.000000
# 13         25130                      BM25   0.2  0.333333  0.166667
# 13         25130  Dirichlet Language Model   0.1  0.166667  0.200000
# 14         25461                      BM25   0.1  0.047619  1.000000
# 14         25461  Dirichlet Language Model   0.2  0.095238  1.000000
# 15          2547                      BM25   0.2  0.125000  1.000000
# 15          2547  Dirichlet Language Model   0.2  0.125000  1.000000
# 16        351608                      BM25   0.1  0.111111  0.333333
# 16        351608  Dirichlet Language Model   0.1  0.111111  0.250000
# 17          4198                      BM25   0.2  0.117647  0.200000
# 17          4198  Dirichlet Language Model   0.2  0.117647  0.200000
# 18          4334                      BM25   0.7  0.014344  0.500000
# 18          4334  Dirichlet Language Model   0.7  0.014344  0.500000
# 19        477200                      BM25   0.3  0.500000  1.000000
# 19        477200  Dirichlet Language Model   0.3  0.500000  1.000000
# 20        488858                      BM25   0.2  0.111111  1.000000
# 20        488858  Dirichlet Language Model   0.2  0.111111  1.000000
# 21         75643                      BM25   0.3  0.375000  1.000000
# 21         75643  Dirichlet Language Model   0.3  0.375000  1.000000
# 22         80219                      BM25   0.1  0.021739  0.333333
# 22         80219  Dirichlet Language Model   0.1  0.021739  0.333333
# 23         80765                      BM25   0.3  0.428571  1.000000
# 23         80765  Dirichlet Language Model   0.3  0.428571  1.000000
# 24         81103                      BM25   0.2  0.074074  1.000000
# 24         81103  Dirichlet Language Model   0.2  0.074074  1.000000
# 25        814731                      BM25   0.3  0.428571  1.000000
# 25        814731  Dirichlet Language Model   0.3  0.428571  1.000000
# 26         90382                      BM25   0.0  0.000000  0.000000
# 26         90382  Dirichlet Language Model   0.0  0.000000  0.000000
# 27         90496                      BM25   0.2  0.142857  1.000000
# 27         90496  Dirichlet Language Model   0.2  0.142857  1.000000
# 28          9748                      BM25   0.2  0.285714  1.000000
# 28          9748  Dirichlet Language Model   0.2  0.285714  1.000000
# 29         97591                      BM25   0.1  0.045455  0.111111
# 29         97591  Dirichlet Language Model   0.1  0.045455  0.111111

# %%
qrels.qid.value_counts() #189225, 196387, 25130
# Out:
# 4334       488
# 125608      77
# 80219       46
# 81103       27
# 97591       22
# 25461       21
# 488858      18
# 4198        17
# 2547        16
# 1403378     15
# 1897191     14
# 90496       14
# 14032       12
# 351608       9
# 113621       9
# 217759       9
# 146323       8
# 90382        8
# 75643        8
# 189225       8
# 157369       8
# 80765        7
# 9748         7
# 22800        7
# 814731       7
# 21439        7
# 196387       6
# 477200       6
# 189034       6
# 25130        6
# Name: qid, dtype: int64

# %%
comp = pd.concat([qrels_DLM.reset_index(), qrels_BM25.reset_index()])
comp = comp.groupby(["qid", "name"]).apply(lambda x: x[["qid", "name", "P@10"]])
comp.head(62)

#25461
# Out:
# measure      qid                      name  P@10
# 0         113621                      BM25   0.0
# 0         113621  Dirichlet Language Model   0.0
# 1         125608                      BM25   0.1
# 1         125608  Dirichlet Language Model   0.1
# 2          14032                      BM25   0.1
# 2          14032  Dirichlet Language Model   0.1
# 3        1403378                      BM25   0.2
# 3        1403378  Dirichlet Language Model   0.2
# 4         146323                      BM25   0.3
# 4         146323  Dirichlet Language Model   0.3
# 5         157369                      BM25   0.5
# 5         157369  Dirichlet Language Model   0.5
# 6         189034                      BM25   0.1
# 6         189034  Dirichlet Language Model   0.1
# 7         189225                      BM25   0.1
# 7         189225  Dirichlet Language Model   0.0
# 8        1897191                      BM25   0.0
# 8        1897191  Dirichlet Language Model   0.0
# 9         196387                      BM25   0.3
# 9         196387  Dirichlet Language Model   0.3
# 10         21439                      BM25   0.4
# 10         21439  Dirichlet Language Model   0.4
# 11        217759                      BM25   0.4
# 11        217759  Dirichlet Language Model   0.4
# 12         22800                      BM25   0.4
# 12         22800  Dirichlet Language Model   0.4
# 13         25130                      BM25   0.2
# 13         25130  Dirichlet Language Model   0.1
# 14         25461                      BM25   0.1
# 14         25461  Dirichlet Language Model   0.2
# 15          2547                      BM25   0.2
# 15          2547  Dirichlet Language Model   0.2
# 16        351608                      BM25   0.1
# 16        351608  Dirichlet Language Model   0.1
# 17          4198                      BM25   0.2
# 17          4198  Dirichlet Language Model   0.2
# 18          4334                      BM25   0.7
# 18          4334  Dirichlet Language Model   0.7
# 19        477200                      BM25   0.3
# 19        477200  Dirichlet Language Model   0.3
# 20        488858                      BM25   0.2
# 20        488858  Dirichlet Language Model   0.2
# 21         75643                      BM25   0.3
# 21         75643  Dirichlet Language Model   0.3
# 22         80219                      BM25   0.1
# 22         80219  Dirichlet Language Model   0.1
# 23         80765                      BM25   0.3
# 23         80765  Dirichlet Language Model   0.3
# 24         81103                      BM25   0.2
# 24         81103  Dirichlet Language Model   0.2
# 25        814731                      BM25   0.3
# 25        814731  Dirichlet Language Model   0.3
# 26         90382                      BM25   0.0
# 26         90382  Dirichlet Language Model   0.0
# 27         90496                      BM25   0.2
# 27         90496  Dirichlet Language Model   0.2
# 28          9748                      BM25   0.2
# 28          9748  Dirichlet Language Model   0.2
# 29         97591                      BM25   0.1
# 29         97591  Dirichlet Language Model   0.1

# %% [markdown]
# **Jika dilihat secara manual, hasil terbaik dari model BM25 ada pada Query ID 189225, 196387, 25130. Query-query tersebut tidak banyak muncul pada dokumen dataset, hanya muncul kurang dari 10 dokumen. Sehingga hasil ini kemungkinan disebabkan oleh kecilnya angka denominatornya (terlebih karena model tidak mempunyai perbedaan signifikan pada performanya).**
#
# **Sedangkan, pada model DLM, query ID terbaik ada pada QID 25461.**

# %% [markdown]
# ### Query ID berapa yang memiliki nilai evaluasi terbaik dengan metode BM25? Query ID berapa yang memiliki nilai evaluasi terbaik dengan metode LM? Berikan analisis Anda mengapa hal ini bisa terjadi.

# %%
comp.reset_index().sort_values("P@10", ascending=False) #	4334
# Out:
# measure  index      qid                      name  P@10
# 37          18     4334  Dirichlet Language Model   0.7
# 36          18     4334                      BM25   0.7
# 10           5   157369                      BM25   0.5
# 11           5   157369  Dirichlet Language Model   0.5
# 20          10    21439                      BM25   0.4
# 24          12    22800                      BM25   0.4
# 23          11   217759  Dirichlet Language Model   0.4
# 22          11   217759                      BM25   0.4
# 21          10    21439  Dirichlet Language Model   0.4
# 25          12    22800  Dirichlet Language Model   0.4
# 9            4   146323  Dirichlet Language Model   0.3
# 8            4   146323                      BM25   0.3
# 42          21    75643                      BM25   0.3
# 46          23    80765                      BM25   0.3
# 50          25   814731                      BM25   0.3
# 43          21    75643  Dirichlet Language Model   0.3
# 47          23    80765  Dirichlet Language Model   0.3
# 18           9   196387                      BM25   0.3
# 19           9   196387  Dirichlet Language Model   0.3
# 38          19   477200                      BM25   0.3
# 39          19   477200  Dirichlet Language Model   0.3
# 51          25   814731  Dirichlet Language Model   0.3
# 31          15     2547  Dirichlet Language Model   0.2
# 29          14    25461  Dirichlet Language Model   0.2
# 34          17     4198                      BM25   0.2
# 35          17     4198  Dirichlet Language Model   0.2
# 30          15     2547                      BM25   0.2
# 26          13    25130                      BM25   0.2
# 41          20   488858  Dirichlet Language Model   0.2
# 48          24    81103                      BM25   0.2
# 49          24    81103  Dirichlet Language Model   0.2
# 54          27    90496                      BM25   0.2
# 7            3  1403378  Dirichlet Language Model   0.2
# 6            3  1403378                      BM25   0.2
# 55          27    90496  Dirichlet Language Model   0.2
# 56          28     9748                      BM25   0.2
# 57          28     9748  Dirichlet Language Model   0.2
# 40          20   488858                      BM25   0.2
# 45          22    80219  Dirichlet Language Model   0.1
# 44          22    80219                      BM25   0.1
# 58          29    97591                      BM25   0.1
# 59          29    97591  Dirichlet Language Model   0.1
# 33          16   351608  Dirichlet Language Model   0.1
# 14           7   189225                      BM25   0.1
# 2            1   125608                      BM25   0.1
# 3            1   125608  Dirichlet Language Model   0.1
# 4            2    14032                      BM25   0.1
# 5            2    14032  Dirichlet Language Model   0.1
# 12           6   189034                      BM25   0.1
# 32          16   351608                      BM25   0.1
# 13           6   189034  Dirichlet Language Model   0.1
# 27          13    25130  Dirichlet Language Model   0.1
# 28          14    25461                      BM25   0.1
# 15           7   189225  Dirichlet Language Model   0.0
# 52          26    90382                      BM25   0.0
# 53          26    90382  Dirichlet Language Model   0.0
# 16           8  1897191                      BM25   0.0
# 17           8  1897191  Dirichlet Language Model   0.0
# 1            0   113621  Dirichlet Language Model   0.0
# 0            0   113621                      BM25   0.0

# %% [markdown]
# **Query ID dengan performa paling baik ada pada QID 4334. Query ini muncul paling banyak di dokumen-dokumen dataset dibanding dengan QID yang lain. Banyaknya kemunculan QID ini memberikan peluang presisi lebih besar dari QID lainnya. Sehingga hasilnya untuk Dirichlet dan BM25 sama-sama merupakan QID dengan Precision terbaik.**

# %% [markdown]
# ### Query ID berapa yang memiliki nilai evaluasi terburuk dengan metode BM25? Query ID berapa yang memiliki nilai evaluasi terburuk dengan metode LM? Berikan analisis Anda mengapa hal ini bisa terjadi.

# %%
comp.reset_index().sort_values("P@10", ascending=True)
# Out:
# measure  index      qid                      name  P@10
# 0            0   113621                      BM25   0.0
# 1            0   113621  Dirichlet Language Model   0.0
# 53          26    90382  Dirichlet Language Model   0.0
# 52          26    90382                      BM25   0.0
# 17           8  1897191  Dirichlet Language Model   0.0
# 16           8  1897191                      BM25   0.0
# 15           7   189225  Dirichlet Language Model   0.0
# 45          22    80219  Dirichlet Language Model   0.1
# 44          22    80219                      BM25   0.1
# 33          16   351608  Dirichlet Language Model   0.1
# 32          16   351608                      BM25   0.1
# 58          29    97591                      BM25   0.1
# 28          14    25461                      BM25   0.1
# 27          13    25130  Dirichlet Language Model   0.1
# 59          29    97591  Dirichlet Language Model   0.1
# 13           6   189034  Dirichlet Language Model   0.1
# 12           6   189034                      BM25   0.1
# 14           7   189225                      BM25   0.1
# 2            1   125608                      BM25   0.1
# 3            1   125608  Dirichlet Language Model   0.1
# 5            2    14032  Dirichlet Language Model   0.1
# 4            2    14032                      BM25   0.1
# 35          17     4198  Dirichlet Language Model   0.2
# 40          20   488858                      BM25   0.2
# 41          20   488858  Dirichlet Language Model   0.2
# 49          24    81103  Dirichlet Language Model   0.2
# 34          17     4198                      BM25   0.2
# 54          27    90496                      BM25   0.2
# 55          27    90496  Dirichlet Language Model   0.2
# 56          28     9748                      BM25   0.2
# 57          28     9748  Dirichlet Language Model   0.2
# 48          24    81103                      BM25   0.2
# 6            3  1403378                      BM25   0.2
# 29          14    25461  Dirichlet Language Model   0.2
# 31          15     2547  Dirichlet Language Model   0.2
# 30          15     2547                      BM25   0.2
# 7            3  1403378  Dirichlet Language Model   0.2
# 26          13    25130                      BM25   0.2
# 18           9   196387                      BM25   0.3
# 19           9   196387  Dirichlet Language Model   0.3
# 51          25   814731  Dirichlet Language Model   0.3
# 50          25   814731                      BM25   0.3
# 47          23    80765  Dirichlet Language Model   0.3
# 46          23    80765                      BM25   0.3
# 42          21    75643                      BM25   0.3
# 9            4   146323  Dirichlet Language Model   0.3
# 39          19   477200  Dirichlet Language Model   0.3
# 38          19   477200                      BM25   0.3
# 8            4   146323                      BM25   0.3
# 43          21    75643  Dirichlet Language Model   0.3
# 25          12    22800  Dirichlet Language Model   0.4
# 24          12    22800                      BM25   0.4
# 23          11   217759  Dirichlet Language Model   0.4
# 22          11   217759                      BM25   0.4
# 21          10    21439  Dirichlet Language Model   0.4
# 20          10    21439                      BM25   0.4
# 10           5   157369                      BM25   0.5
# 11           5   157369  Dirichlet Language Model   0.5
# 36          18     4334                      BM25   0.7
# 37          18     4334  Dirichlet Language Model   0.7

# %%
qrels.qid.value_counts().sort_values() # 113621, 90382, 1897191, 189225 (Dirichlet only)
# Out:
# 25130        6
# 477200       6
# 196387       6
# 189034       6
# 21439        7
# 814731       7
# 22800        7
# 9748         7
# 80765        7
# 157369       8
# 189225       8
# 75643        8
# 90382        8
# 146323       8
# 217759       9
# 113621       9
# 351608       9
# 14032       12
# 90496       14
# 1897191     14
# 1403378     15
# 2547        16
# 4198        17
# 488858      18
# 25461       21
# 97591       22
# 81103       27
# 80219       46
# 125608      77
# 4334       488
# Name: qid, dtype: int64

# %% [markdown]
# **Query ID dengan performa paling buruk ada pada QID 113621, 90382, 1897191, 189225 (QID terakhir hanya terjadi pada Dirichlet). Query merupakan query yang tidak banyak muncul di dokumen dataset. Kemunculan QID pada dataset mempunyai peran besar dalam pengaruhnya terhadap Precision hasil.**
